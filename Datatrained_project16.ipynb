# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\Administrator\Downloads\Absenteeism_at_work_AAA\Absenteeism_at_work.xls")

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
print(df.dtypes)
# Out:
# ID                                 int64
# Reason for absence                 int64
# Month of absence                   int64
# Day of the week                    int64
# Seasons                            int64
# Transportation expense             int64
# Distance from Residence to Work    int64
# Service time                       int64
# Age                                int64
# Work load Average/day              int64
# Hit target                         int64
# Disciplinary failure               int64
# Education                          int64
# Son                                int64
# Social drinker                     int64
# Social smoker                      int64
# Pet                                int64
# Weight                             int64
# Height                             int64
# Body mass index                    int64
# Absenteeism time in hours          int64
# dtype: object

# %%
missing_data = df.isnull()
missing_data.head(15)
# Out:
#        ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0   False               False             False            False    False
# 1   False               False             False            False    False
# 2   False               False             False            False    False
# 3   False               False             False            False    False
# 4   False               False             False            False    False
# 5   False               False             False            False    False
# 6   False               False             False            False    False
# 7   False               False             False            False    False
# 8   False               False             False            False    False
# 9   False               False             False            False    False
# 10  False               False             False            False    False
# 11  False               False             False            False    False
# ...

# %%
df.corr()
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Work load Average/day            0.092457           -0.123472
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# ...

# %%
sns.regplot(x="Reason for absence", y="Absenteeism time in hours", data=df)
plt.ylim(0,)
# Out:
# (0, 126.01669426048565)

# %%
sns.regplot(x="Age", y="Absenteeism time in hours", data=df)
plt.ylim(0,)
# Out:
# (0, 126.01669426048565)

# %%
sns.regplot(x="Distance from Residence to Work", y="Absenteeism time in hours", data=df)
plt.ylim(0,)
# Out:
# (0, 126.01669426048565)

# %%
sns.regplot(x="Son", y="Absenteeism time in hours", data=df)
plt.ylim(0,)
# Out:
# (0, 126.01669426048565)

# %%
sns.regplot(x="Distance from Residence to Work", y="Absenteeism time in hours", data=df)
plt.ylim(0,)
# Out:
# (0, 126.01669426048565)

# %%
sns.regplot(x="Social drinker", y="Absenteeism time in hours", data=df)
plt.ylim(0,)
# Out:
# (0, 126.01669426048565)

# %%
from sklearn.linear_model import LinearRegression

# %%
Z = df[['Transportation expense','Age','Son','Body mass index']]
y = df['Absenteeism time in hours']

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.fit(Z,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Yhat=lm.predict(Z)
Yhat[0:5]
# Out:
# array([6.52933571, 8.52142379, 4.93298204, 9.29876601, 6.52933571])

# %%
lm.fit(Z, y)
print('The R-square is: ', lm.score(Z, y))
# Out:
# The R-square is:  0.021569572141519

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False,degree=6)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=6, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
pipe.fit(Z,y)
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=6, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([11.18603516,  9.08935547,  4.20013428,  4.94689941])

# %%
pipe.fit(Z, y)
# Find the R^2
print('The R-square is: ', pipe.score(Z, y))
# Out:
# The R-square is:  0.09434095439214107
